# %% [markdown]
# # Predicting Houses Damaged based on data from typhoons:
#
# * Melor 12. 2015
# * Hagupit 11/12. 2014
# * Rammasun 07.2014
# * Haiyan 11. 2013

# %%
# %pylab inline
import pandas as pd
import numpy as np
import cPickle
from sklearn import metrics
from sklearn import svm
from sklearn import preprocessing
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
from sklearn.grid_search import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV
from sklearn import cross_validation
from sklearn.cross_validation import  cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import  RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from pandas.tools.plotting import scatter_matrix
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.feature_selection import SelectFromModel
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
T = pd.read_csv("../4 typhoons/matrix_4typhoons.csv")
T.index = T['M_Code']
OriginalT = T

# %%
T.head(5)
# Out:
#              Unnamed: 0       M_Code     Municipality  Area (km2)  \
# M_Code
# PH054120000           1  PH054120000      SAN PASCUAL     256.250
# PH050505000           3  PH050505000         JOVELLAR      80.529
# PH050503000           4  PH050503000  DARAGA (LOCSIN)     123.965
# PH050504000           6  PH050504000       GUINOBATAN     175.450
# PH050508000           8  PH050508000    CITY OF LIGAO     246.894
#
#              Population 2010 census  Population 2015 census  \
# M_Code
# PH054120000                     NaN                   46674
# PH050505000                     NaN                   17308
# PH050503000                     NaN                  126595
# PH050504000                     NaN                   82361
# PH050508000                     NaN                  111399
#
#              Pop. Density 2015 per km2  Poverty (%)  Rainfallme  \
# M_Code
# PH054120000                 182.142439     8.617217  256.035653
# PH050505000                 214.928783    10.399815  249.605511
# PH050503000                1021.215666     4.217386  249.600006
# PH050504000                 469.427187     6.456940  248.047735
# PH050508000                 451.201730     5.798077  245.472074
#
#              Houses damaged  average_speed_mph  distance_typhoon_km  \
# M_Code
# PH054120000             508          89.238502            45.665419
# PH050505000             565          97.944058            28.785653
# PH050503000              91         108.927239            18.583695
# PH050504000            2406         114.198171            15.814282
# PH050508000             572         113.425678            17.048302
#
#             typhoon_name  perc_house_damage
# M_Code
# PH054120000     Rammasun           0.010884
# PH050505000     Rammasun           0.032644
# PH050503000     Rammasun           0.000719
# PH050504000     Rammasun           0.029213
# PH050508000     Rammasun           0.005135

# %% [markdown]
# ## Exploration of data (missing data wrt houses damaged, poeple affected)

# %%
T.typhoon_name.value_counts().plot(kind='bar')

# %%
T.describe().transpose()
# Out:
#                            count          mean           std          min  \
# Unnamed: 0                   924    429.873377    284.645917     1.000000
# Area (km2)                   924    155.774934    159.301424     1.610000
# Population 2010 census       357  41702.885154  45973.449556  4058.000000
# Population 2015 census       924  50593.443723  65378.845418  4034.000000
# Pop. Density 2015 per km2    924    614.797580   1820.456409    17.772679
# Poverty (%)                  917     12.521384     12.738553     0.425403
# Rainfallme                   924    268.855034    143.041407    12.000000
# Houses damaged               924   2071.814935   3060.252058     0.000000
# average_speed_mph            924     97.575575     43.029943     0.000000
# distance_typhoon_km          924     59.233790     50.144322     0.117668
# perc_house_damage            924      0.056223      0.068843     0.000000
#
#                                     25%           50%           75%  \
# Unnamed: 0                   218.750000    387.500000    591.000000
# Area (km2)                    63.556675    115.241850    198.327175
# Population 2010 census     19101.000000  31052.000000  47357.000000
# Population 2015 census     20631.750000  34202.500000  56043.500000
# Pop. Density 2015 per km2    182.080893    292.259084    474.203560
# Poverty (%)                    4.952015      7.529456     10.399815
# Rainfallme                   159.146988    225.600006    351.107788
# Houses damaged                51.000000    706.500000   2962.750000
# average_speed_mph             66.136437     87.529040    119.995781
# distance_typhoon_km           21.498260     47.522074     81.852547
# perc_house_damage              0.001532      0.021302      0.100428
#
#                                      max
# Unnamed: 0                   1588.000000
# Area (km2)                   2204.119900
# Population 2010 census     511820.000000
# Population 2015 census     776386.000000
# Pop. Density 2015 per km2   39652.173910
# Poverty (%)                    59.200000
# Rainfallme                    794.131101
# Houses damaged              20198.000000
# average_speed_mph             190.000000
# distance_typhoon_km           362.007845
# perc_house_damage               0.307500

# %%
scatter_matrix(T, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11335f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113d0c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113d8ded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113df1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113e802d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113eccb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113f57fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113fdbe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114049b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1140c9e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11412fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1141bd050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114166590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11429fb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114321ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11435d650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1143e04d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1144501d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1144d2150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114545f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1145b3b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114637a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11469ca50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11471f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114757ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114810850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148946d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148f68d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114979750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149e1450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114a6b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114aee3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114b50e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114bd3c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114c37cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114cb9c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114cc7fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114dabad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e2e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e94b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114f169d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114f806d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114ff5110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11506bbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1150db910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11515af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1151b5a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11523fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1152c5d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115331a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1153b78d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11541c810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11549e690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115506390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115590490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115612310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115673d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1156f8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11575cc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157deb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1157edf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1158d0a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115953890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1159b7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115a3b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115aa2610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115b2c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115bb0590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115bfaa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115c8b1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115cef610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115d70a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115df4910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115e62610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115ee6490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115f4b3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115fcc250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116028f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1160bf050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116134e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1161a4910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116224790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11628c7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11630f750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116348850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1164005d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116484450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1164e7650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11656a4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1165d11d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11665b2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1166e0150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116740b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1167c3a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115bd3350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116897110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11690db10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1169b7510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a3aa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a9f7d0>]], dtype=object)

# %%
T[['Houses damaged',   'typhoon_name']].boxplot(by='typhoon_name')

# %%
T[['average_speed_mph', 'typhoon_name']].boxplot(by='typhoon_name')

# %% [markdown]
# ### Houses damaged per municipality depending on typhoon

# %%
hd = pd.DataFrame(T[u'M_Code'])
hd.index = hd['M_Code']
del hd['M_Code']
haiyan = T.loc[T['typhoon_name'] == 'Haiyan']['Houses damaged']
# hagupit = T.loc[T['typhoon_name'] == 'Hagupit']['Houses damaged']
# rammasun = T.loc[T['typhoon_name'] == 'Rammasun']['Houses damaged']
melor = T.loc[T['typhoon_name'] == 'Melor']['Houses damaged']
haiyan.plot()
melor.plot(figsize=(20,7))
# rammasun.plot()
# hagupit.plot(figsize=(20,7))

# %%
T[['average_speed_mph']].plot(figsize=(20,5))

# %%
T.loc[T['typhoon_name'] == 'Hagupit'].plot(kind='scatter', x='average_speed_mph', y = 'Houses damaged')

# %%
T.loc[T['typhoon_name'] == 'Hagupit'].sort(columns=['average_speed_mph'], ascending=False).head(10)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#              Unnamed: 0       M_Code      Municipality  Area (km2)  \
# M_Code
# PH086022000         923  PH086022000  PARANAS (WRIGHT)     512.804
# PH086012000         913  PH086012000           MOTIONG     125.595
# PH086009000         910  PH086009000           JIABONG     121.677
# PH086025000         926  PH086025000         SAN JORGE     268.625
# PH086008000         909  PH086008000        HINABANGAN     400.713
# PH086015000         916  PH086015000     SAN SEBASTIAN      32.547
# PH086018000         919  PH086018000       SANTO NI��O      29.983
# PH086020000         921  PH086020000         TARANGNAN      86.758
# PH086026000         927  PH086026000        PAGSANGHAN      33.203
# PH084821000         898  PH084821000       SAN VICENTE      18.215
#
#              Population 2010 census  Population 2015 census  \
# M_Code
# PH086022000                     NaN                   30557
# PH086012000                     NaN                   15156
# PH086009000                     NaN                   18342
# PH086025000                     NaN                   17184
# PH086008000                     NaN                   13673
# PH086015000                     NaN                    8057
# PH086018000                     NaN                   12863
# PH086020000                     NaN                   24992
# PH086026000                     NaN                    7945
# PH084821000                     NaN                    7856
#
#              Pop. Density 2015 per km2  Poverty (%)  Rainfallme  \
# M_Code
# PH086022000                  59.588069     6.823314  244.562655
# PH086012000                 120.673594     8.755608  246.527290
# PH086009000                 150.743361     7.043943  248.795105
# PH086025000                  63.970219     8.531192  252.386292
# PH086008000                  34.121678     7.789073  244.533148
# PH086015000                 247.549697     8.377808  239.481818
# PH086018000                 429.009772     9.523439  280.799988
# PH086020000                 288.065654     9.030890  248.920177
# PH086026000                 239.285607     8.709880  247.280903
# PH084821000                 431.292890     8.235743  208.800003
#
#              Houses damaged  average_speed_mph  distance_typhoon_km  \
# M_Code
# PH086022000             138         118.494362             2.876762
# PH086012000              50         117.545788             0.117668
# PH086009000             222         115.108844             5.436451
# PH086025000             603         113.038151             9.146775
# PH086008000             365         111.910786            19.922740
# PH086015000             883         110.000000            22.491353
# PH086018000              69         110.000000            13.825681
# PH086020000             192         110.000000             0.953392
# PH086026000             300         110.000000             7.080476
# PH084821000             164         107.629806             0.896797
#
#             typhoon_name
# M_Code
# PH086022000      Hagupit
# PH086012000      Hagupit
# PH086009000      Hagupit
# PH086025000      Hagupit
# PH086008000      Hagupit
# PH086015000      Hagupit
# PH086018000      Hagupit
# PH086020000      Hagupit
# PH086026000      Hagupit
# PH084821000      Hagupit

# %%
T.loc[T['Municipality'] == 'MOTIONG' ][['Municipality','Houses damaged', 'average_speed_mph', 'distance_typhoon_km', 'typhoon_name']
    ][1:]
# Out:
#             Municipality  Houses damaged  average_speed_mph  \
# M_Code
# PH086012000      MOTIONG              50         117.545788
#
#              distance_typhoon_km typhoon_name
# M_Code
# PH086012000             0.117668      Hagupit

# %%
T.loc[T['typhoon_name'] == 'Haiyan'].plot(kind='scatter', x='average_speed_mph', y = 'Houses damaged')

# %%
T.loc[T['typhoon_name'] == 'Rammasun'].plot(kind='scatter', x='average_speed_mph', y = 'Houses damaged')

# %%
T.loc[T['typhoon_name'] == 'Melor'].plot(kind='scatter', x='average_speed_mph', y = 'Houses damaged')

# %%
T.columns
# Out:
# Index([u'Unnamed: 0', u'M_Code', u'Municipality', u'Area (km2)',
#        u'Population 2010 census', u'Population 2015 census',
#        u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',
#        u'Houses damaged', u'average_speed_mph', u'distance_typhoon_km',
#        u'typhoon_name', u'perc_house_damage'],
#       dtype='object')

# %%
T['percentage_of_damaged'] = T['Houses damaged']/ (T['Population 2015 census'] / 6 ) * 100

# %%
T.loc[T['typhoon_name'] == 'Rammasun'].plot(kind='scatter', y = 'percentage_of_damaged', x='average_speed_mph')

# %%
T.loc[T['typhoon_name'] == 'Hagupit'][[ 'average_speed_mph']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bcd2d50>]], dtype=object)

# %%
T[pd.notnull(T['Houses damaged'])].describe().transpose()['count'].plot(kind='barh', figsize=(10,4))

# %%
H = T.loc[T['typhoon_name'] == 'Haiyan']

# %%
H[pd.notnull(H['Houses damaged'])].describe().transpose()['count'].plot(kind='barh', figsize=(10,4))

# %%
pd.DataFrame(T['Population 2015 census'] - T['Population 2010 census']).plot(figsize=(20,5))

# %%
T[['Poverty (%)']].hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b42d910>]], dtype=object)

# %%
T.corr()['Houses damaged'].sort_values().plot(kind='barh',  figsize=(12, 3))

# %%
T.loc[T['typhoon_name'] == 'Haiyan'].corr()['Houses damaged'].sort_values().plot(kind='barh',  figsize=(12, 3))

# %%
T.loc[T['typhoon_name'] == 'Hagupit'].corr()['Houses damaged'].sort_values().plot(kind='barh',  figsize=(12, 3))

# %%
T.loc[T['typhoon_name'] == 'Melor'].corr()['Houses damaged'].sort_values().plot(kind='barh',  figsize=(12, 3))

# %%
T.loc[T['typhoon_name'] == 'Rammasun'].corr()['Houses damaged'].sort_values().plot(kind='barh',  figsize=(12, 3))

# %% [markdown]
# ## 0. Data preparation
# * Deleting Unnamed: 0 column
# * Ignoring Census 2010 data
# * Filling poverty data with mean
# * Adding estimated poor counts

# %%
del T['Unnamed: 0']

# %%
del T['Population 2010 census']

# %%
T[['Poverty (%)']] = T[['Poverty (%)']].fillna(T[['Poverty (%)']].mean())

# %%
T['Poor'] = T['Poverty (%)'] * T['Population 2015 census']

# %%
H = pd.read_csv("../data/Haiyan.csv")
H.index = H['M_Code']

# %%
print len(set(T['M_Code'].unique()).intersection(set(H['M_Code'].unique())))
print
# Out:
# 444

# %%
H.columns
# Out:
# Index([u'Unnamed: 0', u'OBJECTID', u'ISO', u'P_Code', u'M_Code',
#        u'Municipality', u'Area (km2)', u'Avg. Elevation (m)', u'Perimeter (m)',
#        u'Coastline Length (m)', u'C/P Ratio',
#        u'Distance to coastline (m, mean)', u'Distance to coastline (m, stdev)',
#        u'Ruggedness index (mean)', u'Ruggedness index (stdev)',
#        u'Slope (mean)', u'Slope (stdev)', u'Landuse (Most common)',
#        u'Poverty (%)', u'Avg. Windspeed (km/h)',
#        u'Distance from typhoon path (km)', u'Area Flooded (%)', u'Rainfallme',
#        u'Surge Height int. (m)', u'Surge risk class (REACH)',
#        u'People affected', u'People affected (% 2010)', u'Deaths',
#        u'Houses damaged (REACH)', u'Houses damaged (% Shelter Cluster)',
#        u'Emergency shelter (% planned & reached Shelter Cluster)',
#        u'Support to Self Recovery (% planned & reached Shelter Cluster)',
#        u'OCHA CCCM', u'OCHA Education', u'OCHA Early Recovery & Livelyhoods',
#        u'OCHA Food security and Agriculture', u'OCHA Nutrition',
#        u'OCHA Protection', u'OCHA WASH', u'Population 2013 Filled',
#        u'Pop. Density 2013 per km2', u'Affected density',
#        u'Poverty (%) Filled', u'Surge risk', u'Poor', u'% Affected'],
#       dtype='object')

# %% [markdown]
# ## 1. Training the model on Hayan data, evaluating on the rest

# %%
T.columns
# Out:
# Index([u'M_Code', u'Municipality', u'Area (km2)', u'Population 2015 census',
#        u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',
#        u'Houses damaged', u'average_speed_mph', u'distance_typhoon_km',
#        u'typhoon_name', u'perc_house_damage', u'Poor'],
#       dtype='object')

# %%
X1_train = T.loc[T['typhoon_name'] == 'Haiyan'][[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]

y1_train = T.loc[T['typhoon_name'] == 'Haiyan']['Houses damaged']

X1_test = T.loc[T['typhoon_name'] != 'Haiyan'][[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]
y1_test = T.loc[T['typhoon_name'] != 'Haiyan']['Houses damaged']

rf = RandomForestRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [20, 50, 100],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [2, 5, 10, 20]
}
CV_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 10)
CV_rf.fit(X1_train, y1_train)
print CV_rf.best_params_
# Out:
# {'max_features': 'log2', 'n_estimators': 10, 'min_samples_leaf': 5}

# %%
rf = RandomForestRegressor(max_features= 'auto', n_estimators= 100, min_samples_leaf= 10)

predicted1_train_rf = cross_validation.cross_val_predict(rf, X1_train, y1_train, cv=10)

print 'Cross validation MAE: ', mean_absolute_error(y1_train, predicted1_train_rf)
print 'Cross validation R2: ', r2_score(y1_train, predicted1_train_rf)

rf.fit(X1_train, y1_train )

predicted1_train_rf = rf.predict(X1_train)
print 'Training data MAE: ', mean_absolute_error(y1_train, predicted1_train_rf)
print 'Training data R2: ', r2_score(y1_train, predicted1_train_rf)
predicted1_test = rf.predict(X1_test)
print 'MAE on other typhoons: ', mean_absolute_error(y1_test, predicted1_test)
print 'R2 on other typhoons: ', r2_score(y1_test, predicted1_test)
# Out:
# Cross validation MAE:  925.279658451
# Cross validation R2:  0.637270005993
# Training data MAE:  654.537943192
# Training data R2:  0.813135969778
# MAE on other typhoons:  1592.06627512
# R2 on other typhoons:  0.182687400728

# %% [markdown]
# ## 2. Training the model on 2 oldest typhoons, evaluating on the rest

# %%
X2_train = T.loc[T['typhoon_name'].isin(['Haiyan', 'Rammasun' ])][[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)', u'average_speed_mph', u'distance_typhoon_km', u'Poor']]


y2_train = T.loc[T['typhoon_name'].isin(['Haiyan', 'Rammasun'])]['Houses damaged']

X2_test = T.loc[T['typhoon_name'].isin(['Haiyan', 'Rammasun' ]) == False][[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]
y2_test = T.loc[T['typhoon_name'].isin(['Haiyan', 'Rammasun' ]) == False]['Houses damaged']

print "Training shapes: ", X2_train.shape, y2_train.shape
print "Testing shapes: ", X2_test.shape, y2_test.shape
                 
rf = RandomForestRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [50, 100, 150],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [5, 10, 15]
}
CV_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 10)
CV_rf.fit(X2_train, y2_train)
print CV_rf.best_params_
# Out:
# Training shapes:  (640, 7) (640,)
# Testing shapes:  (284, 7) (284,)
# {'max_features': 'sqrt', 'n_estimators': 50, 'min_samples_leaf': 5}

# %%
rf = RandomForestRegressor(max_features= 'auto', n_estimators= 100, min_samples_leaf= 10)

predicted2_train_rf = cross_validation.cross_val_predict(rf, X2_train, y2_train, cv=10)

print 'Cross validation MAE: ', mean_absolute_error(y2_train, predicted2_train_rf)
print 'Cross validation R2: ', r2_score(y2_train, predicted2_train_rf)

rf.fit(X2_train, y2_train )

predicted2_train_rf = rf.predict(X2_train)
print 'Training data MAE: ', mean_absolute_error(y2_train, predicted2_train_rf)
print 'Training data R2: ', r2_score(y2_train, predicted2_train_rf)
predicted2_test = rf.predict(X2_test)
print 'MAE on other typhoons: ', mean_absolute_error(y2_test, predicted2_test)
print 'R2 on other typhoons: ', r2_score(y2_test, predicted2_test)
# Out:
# Cross validation MAE:  1163.36019811
# Cross validation R2:  0.54089394407
# Training data MAE:  852.027662313
# Training data R2:  0.745018604928
# MAE on other typhoons:  1599.93674509
# R2 on other typhoons:  0.41834940587

# %% [markdown]
# ## 3. Crossvalidation Training the model on 3 typhoons, leaving one for testing

# %%
# best cross val parameters

# %%
X = T[[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]

y = T['Houses damaged']

# %%
rf = RandomForestRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [10, 20, 50, 100],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [2, 5, 10, 20]
}
CV_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 10)
CV_rf.fit(X, y)
print CV_rf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 50, 'min_samples_leaf': 5}

# %%
gb = GradientBoostingRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [10, 20, 50, 100],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [2, 5, 10, 20]
}
CV = GridSearchCV(estimator=gb, param_grid=param_grid, cv= 10)
CV.fit(X, y)
print CV.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100, 'min_samples_leaf': 10}

# %%
typhoons = [  'Haiyan', 'Rammasun','Hagupit', 'Melor']



rf = RandomForestRegressor(max_features= 'sqrt', n_estimators= 50, min_samples_leaf= 2)
gb = GradientBoostingRegressor(max_features= 'sqrt', n_estimators= 100, min_samples_leaf= 10)
models = [gb, rf]

for model in models: 
    print '\n\n-------------------'
    print '\n\n',str(model)
    print '\n\n-------------------'
    all_mae = []
    all_r2 = []

    for i in range(4): 
        selected = [t for t in typhoons if typhoons[i]!=t]
        print '\n\nTraining on ', selected
        print 'Testing on  ', typhoons[i]


        X3_train = T.loc[T['typhoon_name'].isin(selected)][[u'Area (km2)', u'Population 2015 census',
           u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]


        y3_train = T.loc[T['typhoon_name'].isin(selected)]['Houses damaged']

        X3_test = T.loc[T['typhoon_name'].isin(selected) == False][[u'Area (km2)', u'Population 2015 census',
           u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', u'Poor']]
        y3_test = T.loc[T['typhoon_name'].isin(selected) == False]['Houses damaged']


        model.fit(X3_train, y3_train )


        mae_test = []
        r2_test = []
        runs = 100
        for i in range(runs): 
            predicted3_test = model.predict(X3_test)
            mae_test.append(mean_absolute_error(y3_test, predicted3_test))
            r2_test.append(r2_score(y3_test, predicted3_test))

        print 'MAE (average from ', runs, ' runs): ', np.mean(mae_test)
        print 'R2 (average from ', runs, ' runs): ', np.mean(r2_test)
        all_mae.extend(mae_test)
        all_r2.extend(r2_test)

    outcome = pd.DataFrame({'Houses damaged': y3_test, 'PredictedRF': predicted3_test})
    outcome.plot(figsize=(14, 5), color=['red', 'blue', 'darkgreen'])


    print '\nCross validation MAE (average from ', runs, ' runs): ', np.mean(all_mae)
    print 'Cross validation R2 (average from ', runs, ' runs): ', np.mean(all_r2)
# Out:
# -------------------
#
#
# GradientBoostingRegressor(alpha=0.9, init=None, learning_rate=0.1, loss='ls',
#              max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=100,
#              presort='auto', random_state=None, subsample=1.0, verbose=0,
#              warm_start=False)
#
#
# -------------------
#
#
# Training on  ['Rammasun', 'Hagupit', 'Melor']
# Testing on   Haiyan
# MAE (average from  100  runs):  2720.16670449
# R2 (average from  100  runs):  -0.159470854073
#
#
# Training on  ['Haiyan', 'Hagupit', 'Melor']
# Testing on   Rammasun
# MAE (average from  100  runs):  1652.52149815
# R2 (average from  100  runs):  0.147179674789
#
#
# Training on  ['Haiyan', 'Rammasun', 'Melor']
# Testing on   Hagupit
# MAE (average from  100  runs):  1577.29407957
# R2 (average from  100  runs):  0.0534081046433
#
#
# Training on  ['Haiyan', 'Rammasun', 'Hagupit']
# Testing on   Melor
# MAE (average from  100  runs):  1790.1707708
# R2 (average from  100  runs):  0.560810526128
#
# Cross validation MAE (average from  100  runs):  1935.03826325
# Cross validation R2 (average from  100  runs):  0.150481862872
#
#
# -------------------
#
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=2,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
#
#
# -------------------
#
#
# Training on  ['Rammasun', 'Hagupit', 'Melor']
# Testing on   Haiyan
# MAE (average from  100  runs):  2322.96238708
# R2 (average from  100  runs):  0.135511027892
#
#
# Training on  ['Haiyan', 'Hagupit', 'Melor']
# Testing on   Rammasun
# MAE (average from  100  runs):  1498.56101294
# R2 (average from  100  runs):  0.313557713105
#
#
# Training on  ['Haiyan', 'Rammasun', 'Melor']
# Testing on   Hagupit
# MAE (average from  100  runs):  1478.31464343
# R2 (average from  100  runs):  0.123764015049
#
#
# Training on  ['Haiyan', 'Rammasun', 'Hagupit']
# Testing on   Melor
# MAE (average from  100  runs):  1846.22496443
# R2 (average from  100  runs):  0.492154375207
#
# Cross validation MAE (average from  100  runs):  1786.51575197
# Cross validation R2 (average from  100  runs):  0.266246782813

# %%
outcome = pd.DataFrame({'Houses damaged': y3_test, 'PredictedRF': predicted3_test})
outcome.plot(figsize=(14, 5), color=['red', 'blue', 'darkgreen'])

# %% [markdown]
# ### Gradient boost

# %%
gb = GradientBoostingRegressor(max_features= 'log2', n_estimators= 100, min_samples_leaf= 5)

param_grid = { 
    'n_estimators': [ 50, 75, 100],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [ 5, 10, 20]
}
CV_rf = GridSearchCV(estimator=gb, param_grid=param_grid, cv= 10)
CV_rf.fit(X, y)
print CV_rf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100, 'min_samples_leaf': 10}

# %%
gb = GradientBoostingRegressor(max_features= 'sqrt', n_estimators= 100, min_samples_leaf= 10)

predicted3_train_gb = cross_validation.cross_val_predict(rf, X3_train, y3_train, cv=10)

print 'Cross validation MAE: ', mean_absolute_error(y3_train, predicted3_train_gb)
print 'Cross validation R2: ', r2_score(y3_train, predicted3_train_gb)

gb.fit(X3_train, y3_train )


mae_test = []
r2_test = []
for i in range(100): 
    predicted3_train_gb = gb.predict(X3_train)
    predicted3_test = gb.predict(X3_test)
    mae_test.append(mean_absolute_error(y3_test, predicted3_test))
    r2_test.append(r2_score(y3_test, predicted3_test))
    
# print 'Training data MAE: ', mean_absolute_error(y3_train, predicted3_train_gb)
# print 'Training data R2: ', r2_score(y3_train, predicted3_train_gb)

print 'MAE measured on last typhoon (average from 100 runs): ', np.mean(mae_test)
print 'R2 measured on last typhoons (average from 100 runs): ', np.mean(r2_test)
# Out:
# Cross validation MAE:  1279.4693895
# Cross validation R2:  0.463126199968
# MAE measured on last typhoon (average from 100 runs):  1775.19075636
# R2 measured on last typhoons (average from 100 runs):  0.575703103816

# %%
outcome = pd.DataFrame({'Houses damaged': y4_test, 'PredictedRF': predicted4_test})
outcome.plot(figsize=(14, 5), color=['red', 'blue', 'darkgreen'])

# %% [markdown]
# ## 5th model trained on all typhoons, can be used for prediction for the coming typhoon

# %%
### with rainfall

# %%
X5_train = T[[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)', u'Rainfallme',  u'average_speed_mph', u'distance_typhoon_km', 'Poor']]


y5_train = T['Houses damaged']


print "Training shapes: ", X5_train.shape, y5_train.shape
# Out:
# Training shapes:  (924, 8) (924,)

# %%
rf = RandomForestRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [50, 100, 150, 200],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [5, 10, 20]
}
CV_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 10)
CV_rf.fit(X5_train, y5_train)
print CV_rf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 50, 'min_samples_leaf': 5}

# %%
rf = RandomForestRegressor(max_features= 'log2', n_estimators= 100, min_samples_leaf= 10)

rf.fit(X5_train, y5_train )

mae_cv = []
r2_cv = []
runs = 50
for i in range(runs): 
    predicted5_train_rf = cross_validation.cross_val_predict(rf, X5_train, y5_train, cv=10)
    mae_cv.append(mean_absolute_error(y5_train, predicted5_train_rf))
    r2_cv.append(r2_score(y5_train, predicted5_train_rf))
    
print 'Cross validation MAE (average from ',runs,' runs): ', np.mean(mae_cv)
print 'Cross validation R2 (average from ',runs,' runs): ', np.mean(r2_cv)
# Out:
# Cross validation MAE (average from  50  runs):  1350.02980244
# Cross validation R2 (average from  50  runs):  0.481417070049

# %%
gb = GradientBoostingRegressor(max_features= 'sqrt', n_estimators= 100, min_samples_leaf= 10)


gb.fit(X5_train, y5_train )


mae_cv = []
r2_cv = []
runs = 50
for i in range(runs): 
    predicted5_train_gb = cross_validation.cross_val_predict(gb, X5_train, y5_train, cv=10)
    mae_cv.append(mean_absolute_error(y5_train, predicted5_train_gb))
    r2_cv.append(r2_score(y5_train, predicted5_train_gb))
    
print 'Cross validation MAE (average from ',runs,' runs): ', np.mean(mae_cv)
print 'Cross validation R2 (average from ',runs,' runs): ', np.mean(r2_cv)
# Out:
# Cross validation MAE (average from  50  runs):  1376.06487991
# Cross validation R2 (average from  50  runs):  0.458976194363

# %% [markdown]
# #### no rainfall

# %%
X5_train = T[[u'Area (km2)', u'Population 2015 census',
       u'Pop. Density 2015 per km2', u'Poverty (%)',   u'average_speed_mph', u'distance_typhoon_km', 'Poor']]

y5_train = T['Houses damaged']


print "Training shapes: ", X5_train.shape, y5_train.shape

# %%
rf = RandomForestRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [50, 100, 150, 200],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [5, 10, 20]
}
CV_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 10)
CV_rf.fit(X5_train, y5_train)
print CV_rf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 50, 'min_samples_leaf': 5}

# %%
gb = GradientBoostingRegressor(n_estimators=200)
param_grid = { 
    'n_estimators': [50, 100, 150, 200],
    'max_features': ['auto', 'sqrt', 'log2'], 
    'min_samples_leaf': [5, 10, 20]
}
CV_rf = GridSearchCV(estimator=gb, param_grid=param_grid, cv= 10)
CV_rf.fit(X5_train, y5_train)
print CV_rf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100, 'min_samples_leaf': 10}

# %%
gb = GradientBoostingRegressor(max_features= 'sqrt', n_estimators= 100, min_samples_leaf= 10)


gb.fit(X5_train, y5_train )


mae_cv = []
r2_cv = []
for i in range(100): 
    predicted5_train_gb = cross_validation.cross_val_predict(gb, X5_train, y5_train, cv=10)
    mae_cv.append(mean_absolute_error(y5_train, predicted5_train_gb))
    r2_cv.append(r2_score(y5_train, predicted5_train_gb))
    
print 'Cross validation MAE (average from 100 runs): ', np.mean(mae_cv)
print 'Cross validation R2 (average from 100 runs): ', np.mean(r2_cv)
# Out:
# Cross validation MAE (average from 100 runs):  1372.3767145
# Cross validation R2 (average from 100 runs):  0.462781459803

# %%
rf = RandomForestRegressor(max_features= 'sqrt', n_estimators= 50, min_samples_leaf= 5)

rf.fit(X5_train, y5_train )

mae_cv = []
r2_cv = []
for i in range(100): 
    predicted5_train_rf = cross_validation.cross_val_predict(rf, X5_train, y5_train, cv=10)
    mae_cv.append(mean_absolute_error(y5_train, predicted5_train_rf))
    r2_cv.append(r2_score(y5_train, predicted5_train_rf))
    
print 'Cross validation MAE (average from 100 runs): ', np.mean(mae_cv)
print 'Cross validation R2 (average from 100 runs): ', np.mean(r2_cv)
# Out:
# Cross validation MAE (average from 100 runs):  1351.7339514
# Cross validation R2 (average from 100 runs):  0.47980578337

# %% [markdown]
# ## 6. Saving the model

# %%
with open('Model_Hayian_Melor_Hagupit_Ramasun', 'wb') as f:
    cPickle.dump(rf, f)


# Using for prediction saved model
